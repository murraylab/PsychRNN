# %%
import sisyphus2
from sisyphus2.tasks import rdm as rd
from sisyphus2.backend.models.basic import Basic
import tensorflow as tf

from matplotlib import pyplot as plt
# %matplotlib inline

rdm = rd.RDM(dt = 10, tau = 100, T = 2000, N_batch = 128)
gen = rdm.batch_generator()

params = rdm.__dict__
params['name'] = 'model'
params['N_rec'] = 50

model = Basic(params)
model.build()
model.train(gen)

x,_,_ = gen.next()

plt.plot(model.test(x)[0][0,:,:])

model.destruct()
# Out:
# Iter 1280, Minibatch Loss= 0.149658
# Iter 2560, Minibatch Loss= 0.132961
# Iter 3840, Minibatch Loss= 0.131200
# Iter 5120, Minibatch Loss= 0.130312
# Iter 6400, Minibatch Loss= 0.121008
# Iter 7680, Minibatch Loss= 0.124517
# Iter 8960, Minibatch Loss= 0.115667
# Optimization finished!
